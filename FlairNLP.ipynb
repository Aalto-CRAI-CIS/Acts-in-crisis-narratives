# %%
# !python -m pip install --user flair --upgrade
# !python -m pip install --user optuna==3.1.0
# Out:
# Requirement already up-to-date: flair in ./env/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied, skipping upgrade: gdown==4.4.0 in ./env/lib/python3.9/site-packages (from flair) (4.4.0)
# Requirement already satisfied, skipping upgrade: segtok>=1.5.7 in ./env/lib/python3.9/site-packages (from flair) (1.5.11)
# Requirement already satisfied, skipping upgrade: gensim>=3.8.0 in /usr/local/lib64/python3.9/site-packages (from flair) (4.3.1)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.21.3 in /usr/local/lib64/python3.9/site-packages (from flair) (1.2.2)
# Requirement already satisfied, skipping upgrade: hyperopt>=0.2.7 in ./env/lib/python3.9/site-packages (from flair) (0.2.7)
# Requirement already satisfied, skipping upgrade: bpemb>=0.3.2 in ./env/lib/python3.9/site-packages (from flair) (0.3.4)
# Requirement already satisfied, skipping upgrade: pptree in ./env/lib/python3.9/site-packages (from flair) (3.1)
# Requirement already satisfied, skipping upgrade: janome in ./env/lib/python3.9/site-packages (from flair) (0.4.2)
# Requirement already satisfied, skipping upgrade: deprecated>=1.2.4 in ./env/lib/python3.9/site-packages (from flair) (1.2.13)
# Requirement already satisfied, skipping upgrade: langdetect in ./env/lib/python3.9/site-packages (from flair) (1.0.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.9/site-packages (from flair) (2.8.2)
# Requirement already satisfied, skipping upgrade: ftfy in ./env/lib/python3.9/site-packages (from flair) (6.1.1)
# Requirement already satisfied, skipping upgrade: regex in /usr/local/lib64/python3.9/site-packages (from flair) (2022.10.31)
# Requirement already satisfied, skipping upgrade: torch!=1.8,>=1.5.0 in /usr/local/lib64/python3.9/site-packages (from flair) (2.0.0)
# Requirement already satisfied, skipping upgrade: conllu>=4.0 in ./env/lib/python3.9/site-packages (from flair) (4.5.2)
# Requirement already satisfied, skipping upgrade: wikipedia-api in ./env/lib/python3.9/site-packages (from flair) (0.5.8)
# Requirement already satisfied, skipping upgrade: more-itertools in ./env/lib/python3.9/site-packages (from flair) (9.0.0)
# Requirement already satisfied, skipping upgrade: pytorch-revgrad in ./env/lib/python3.9/site-packages (from flair) (0.2.0)
# Requirement already satisfied, skipping upgrade: transformer-smaller-training-vocab>=0.2.1 in ./env/lib/python3.9/site-packages (from flair) (0.2.4)
# Requirement already satisfied, skipping upgrade: mpld3==0.3 in ./env/lib/python3.9/site-packages (from flair) (0.3)
# Requirement already satisfied, skipping upgrade: tabulate in /usr/local/lib/python3.9/site-packages (from flair) (0.9.0)
# Requirement already satisfied, skipping upgrade: lxml in /usr/local/lib64/python3.9/site-packages (from flair) (4.9.2)
# Requirement already satisfied, skipping upgrade: huggingface-hub>=0.10.0 in ./env/lib/python3.9/site-packages (from flair) (0.10.0)
# Requirement already satisfied, skipping upgrade: transformers[sentencepiece]>=4.18.0 in /usr/local/lib/python3.9/site-packages (from flair) (4.27.2)
# Requirement already satisfied, skipping upgrade: boto3 in ./env/lib/python3.9/site-packages (from flair) (1.26.84)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.2.3 in /usr/local/lib64/python3.9/site-packages (from flair) (3.7.1)
# Requirement already satisfied, skipping upgrade: tqdm>=4.26.0 in /usr/local/lib/python3.9/site-packages (from flair) (4.65.0)
# Requirement already satisfied, skipping upgrade: sqlitedict>=1.6.0 in ./env/lib/python3.9/site-packages (from flair) (2.1.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.9/site-packages (from gdown==4.4.0->flair) (1.16.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/local/lib/python3.9/site-packages (from gdown==4.4.0->flair) (4.12.0)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.9/site-packages (from gdown==4.4.0->flair) (3.10.0)
# Requirement already satisfied, skipping upgrade: requests[socks] in /usr/local/lib/python3.9/site-packages (from gdown==4.4.0->flair) (2.28.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.18.5 in /usr/local/lib64/python3.9/site-packages (from gensim>=3.8.0->flair) (1.23.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.7.0 in /usr/local/lib64/python3.9/site-packages (from gensim>=3.8.0->flair) (1.9.1)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.9/site-packages (from gensim>=3.8.0->flair) (6.3.0)
# Requirement already satisfied, skipping upgrade: joblib>=1.1.1 in /usr/local/lib/python3.9/site-packages (from scikit-learn>=0.21.3->flair) (1.2.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn>=0.21.3->flair) (3.1.0)
# Requirement already satisfied, skipping upgrade: cloudpickle in /usr/local/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair) (2.2.1)
# Requirement already satisfied, skipping upgrade: future in ./env/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair) (0.18.3)
# Requirement already satisfied, skipping upgrade: networkx>=2.2 in /usr/local/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair) (3.0)
# Requirement already satisfied, skipping upgrade: py4j in ./env/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair) (0.10.9.7)
# Requirement already satisfied, skipping upgrade: sentencepiece in ./env/lib/python3.9/site-packages (from bpemb>=0.3.2->flair) (0.1.97)
# Requirement already satisfied, skipping upgrade: wrapt<2,>=1.10 in ./env/lib/python3.9/site-packages (from deprecated>=1.2.4->flair) (1.15.0)
# Requirement already satisfied, skipping upgrade: wcwidth>=0.2.5 in /usr/local/lib/python3.9/site-packages (from ftfy->flair) (0.2.6)
# Requirement already satisfied, skipping upgrade: nvidia-cusolver-cu11==11.4.0.1; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (11.4.0.1)
# Requirement already satisfied, skipping upgrade: sympy in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (1.11.1)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (11.7.99)
# Requirement already satisfied, skipping upgrade: nvidia-cufft-cu11==10.9.0.58; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (10.9.0.58)
# Requirement already satisfied, skipping upgrade: nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (10.2.10.91)
# Requirement already satisfied, skipping upgrade: triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib64/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (2.0.0)
# Requirement already satisfied, skipping upgrade: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (4.5.0)
# Requirement already satisfied, skipping upgrade: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (8.5.0.96)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-cupti-cu11==11.7.101; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (11.7.101)
# Requirement already satisfied, skipping upgrade: nvidia-cusparse-cu11==11.7.4.91; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (11.7.4.91)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (11.7.99)
# Requirement already satisfied, skipping upgrade: jinja2 in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (3.1.2)
# Requirement already satisfied, skipping upgrade: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (11.10.3.66)
# Requirement already satisfied, skipping upgrade: nvidia-nccl-cu11==2.14.3; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (2.14.3)
# Requirement already satisfied, skipping upgrade: nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64" in /usr/local/lib/python3.9/site-packages (from torch!=1.8,>=1.5.0->flair) (11.7.91)
# Requirement already satisfied, skipping upgrade: datasets<3.0.0,>=2.0.0 in /usr/local/lib/python3.9/site-packages (from transformer-smaller-training-vocab>=0.2.1->flair) (2.10.1)
# Requirement already satisfied, skipping upgrade: pyyaml>=5.1 in /usr/local/lib64/python3.9/site-packages (from huggingface-hub>=0.10.0->flair) (6.0)
# Requirement already satisfied, skipping upgrade: packaging>=20.9 in /usr/local/lib/python3.9/site-packages (from huggingface-hub>=0.10.0->flair) (23.0)
# Requirement already satisfied, skipping upgrade: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib64/python3.9/site-packages (from transformers[sentencepiece]>=4.18.0->flair) (0.13.2)
# Requirement already satisfied, skipping upgrade: protobuf<=3.20.2; extra == "sentencepiece" in ./env/lib/python3.9/site-packages (from transformers[sentencepiece]>=4.18.0->flair) (3.20.2)
# Requirement already satisfied, skipping upgrade: botocore<1.30.0,>=1.29.84 in ./env/lib/python3.9/site-packages (from boto3->flair) (1.29.84)
# Requirement already satisfied, skipping upgrade: jmespath<2.0.0,>=0.7.1 in ./env/lib/python3.9/site-packages (from boto3->flair) (1.0.1)
# Requirement already satisfied, skipping upgrade: s3transfer<0.7.0,>=0.6.0 in ./env/lib/python3.9/site-packages (from boto3->flair) (0.6.0)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /usr/local/lib64/python3.9/site-packages (from matplotlib>=2.2.3->flair) (9.4.0)
# Requirement already satisfied, skipping upgrade: fonttools>=4.22.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=2.2.3->flair) (4.39.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib>=2.2.3->flair) (0.11.0)
# Requirement already satisfied, skipping upgrade: contourpy>=1.0.1 in /usr/local/lib64/python3.9/site-packages (from matplotlib>=2.2.3->flair) (1.0.7)
# Requirement already satisfied, skipping upgrade: importlib-resources>=3.2.0; python_version < "3.10" in /usr/local/lib/python3.9/site-packages (from matplotlib>=2.2.3->flair) (5.12.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib64/python3.9/site-packages (from matplotlib>=2.2.3->flair) (1.4.4)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.3.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=2.2.3->flair) (3.0.9)
# Requirement already satisfied, skipping upgrade: soupsieve>1.2 in /usr/local/lib/python3.9/site-packages (from beautifulsoup4->gdown==4.4.0->flair) (2.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown==4.4.0->flair) (2022.12.7)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown==4.4.0->flair) (1.26.15)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /usr/local/lib64/python3.9/site-packages (from requests[socks]->gdown==4.4.0->flair) (3.1.0)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown==4.4.0->flair) (3.4)
# Requirement already satisfied, skipping upgrade: PySocks!=1.5.7,>=1.5.6; extra == "socks" in ./env/lib/python3.9/site-packages (from requests[socks]->gdown==4.4.0->flair) (1.7.1)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /usr/local/lib/python3.9/site-packages (from sympy->torch!=1.8,>=1.5.0->flair) (1.3.0)
# Requirement already satisfied, skipping upgrade: setuptools in ./env/lib/python3.9/site-packages (from nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64"->torch!=1.8,>=1.5.0->flair) (50.3.2)
# Requirement already satisfied, skipping upgrade: wheel in /usr/local/lib/python3.9/site-packages (from nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64"->torch!=1.8,>=1.5.0->flair) (0.40.0)
# Requirement already satisfied, skipping upgrade: lit in /usr/local/lib/python3.9/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch!=1.8,>=1.5.0->flair) (16.0.0)
# Requirement already satisfied, skipping upgrade: cmake in /usr/local/lib64/python3.9/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch!=1.8,>=1.5.0->flair) (3.26.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=2.0 in /usr/local/lib64/python3.9/site-packages (from jinja2->torch!=1.8,>=1.5.0->flair) (2.1.2)
# Requirement already satisfied, skipping upgrade: responses<0.19 in /usr/local/lib/python3.9/site-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (0.18.0)
# Requirement already satisfied, skipping upgrade: aiohttp in /usr/local/lib64/python3.9/site-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (3.8.4)
# Requirement already satisfied, skipping upgrade: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/site-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (2023.3.0)
# Requirement already satisfied, skipping upgrade: pyarrow>=6.0.0 in /usr/local/lib64/python3.9/site-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (11.0.0)
# Requirement already satisfied, skipping upgrade: xxhash in /usr/local/lib64/python3.9/site-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (3.2.0)
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib64/python3.9/site-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (1.5.3)
# Requirement already satisfied, skipping upgrade: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/site-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (0.3.6)
# Requirement already satisfied, skipping upgrade: multiprocess in /usr/local/lib/python3.9/site-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (0.70.14)
# Requirement already satisfied, skipping upgrade: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.9/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=2.2.3->flair) (3.15.0)
# Requirement already satisfied, skipping upgrade: frozenlist>=1.1.1 in /usr/local/lib64/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (1.3.3)
# Requirement already satisfied, skipping upgrade: aiosignal>=1.1.2 in /usr/local/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (1.3.1)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /usr/local/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (22.2.0)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /usr/local/lib64/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (6.0.4)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /usr/local/lib64/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (1.8.2)
# Requirement already satisfied, skipping upgrade: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (4.0.2)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (2022.7.1)
# WARNING: You are using pip version 20.2.4; however, version 23.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: optuna==3.1.0 in ./env/lib/python3.9/site-packages (3.1.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib64/python3.9/site-packages (from optuna==3.1.0) (2.0.7)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.9/site-packages (from optuna==3.1.0) (1.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from optuna==3.1.0) (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib64/python3.9/site-packages (from optuna==3.1.0) (1.23.5)
# Requirement already satisfied: PyYAML in /usr/local/lib64/python3.9/site-packages (from optuna==3.1.0) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from optuna==3.1.0) (23.0)
# Requirement already satisfied: colorlog in ./env/lib/python3.9/site-packages (from optuna==3.1.0) (6.7.0)
# Requirement already satisfied: cmaes>=0.9.1 in ./env/lib/python3.9/site-packages (from optuna==3.1.0) (0.9.1)
# Requirement already satisfied: greenlet!=0.4.17; platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32"))))) in /usr/local/lib64/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna==3.1.0) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna==3.1.0) (4.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.9/site-packages (from alembic>=1.5.0->optuna==3.1.0) (1.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib64/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna==3.1.0) (2.1.2)
# WARNING: You are using pip version 20.2.4; however, version 23.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
from flair.data import Sentence
from flair.data import Corpus
from flair.trainers import ModelTrainer
from flair.models import TARSClassifier

import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from optuna.trial import TrialState

from sklearn.metrics import f1_score, balanced_accuracy_score, accuracy_score

# %%
### Configs:
random_state = 72
two_label = False
second_label_confidence = 0.75
three_label = False
third_label_confidence = 0.5
dev_ratio = 0.15
test_ratio = 0.20
multi_label = two_label or three_label

# %% [markdown]
# ## Loading training data

# %%
train = pd.read_csv('new_splited_data/train_13classes.csv')
test = pd.read_csv('new_splited_data/test_13classes.csv')
dev = pd.read_csv('new_splited_data/dev_13classes.csv')

# %%
train['primary tag'].value_counts().index
# Out:
# Index(['informing statement', 'challenge', 'accusation', 'appreciation',
#        'request', 'evaluation', 'rejection', 'question', 'acceptance',
#        'proposal', 'denial', 'admission', 'apology'],
#       dtype='object')

# %%
data = {'train': train, 'dev': dev, 'test':test}
train.shape, test.shape, dev.shape
# Out:
# ((406, 5), (135, 5), (135, 5))

# %% [markdown]
# ## Preparing data for Flair NLP

# %%
sentences = {}
for i, d in data.items():
    sentences[i] = list()
    for j, row in d.iterrows():
        sentences[i].append(Sentence(row['Text']).add_label('action', row['primary tag'], 1.0))
        if two_label and str(row['secondary tag']) != 'nan':
            sentences[i][-1].add_label('action', row['secondary tag'], second_label_confidence)
        if three_label and str(row['tertiary']) != 'nan':
            sentences[i][-1].add_label('action', row['tertiary'], third_label_confidence)

# %%
corpus = Corpus(**sentences)
corpus.obtain_statistics()
# Out:
# '{\n    "TRAIN": {\n        "dataset": "TRAIN",\n        "total_number_of_documents": 406,\n        "number_of_documents_per_class": {\n            "request": 29,\n            "evaluation": 28,\n            "acceptance": 20,\n            "informing statement": 89,\n            "accusation": 48,\n            "rejection": 26,\n            "question": 26,\n            "appreciation": 35,\n            "challenge": 61,\n            "denial": 13,\n            "proposal": 18,\n            "admission": 8,\n            "apology": 5\n        },\n        "number_of_tokens_per_tag": {},\n        "number_of_tokens": {\n            "total": 11507,\n            "min": 1,\n            "max": 566,\n            "avg": 28.342364532019705\n        }\n    },\n    "TEST": {\n        "dataset": "TEST",\n        "total_number_of_documents": 135,\n        "number_of_documents_per_class": {\n            "appreciation": 11,\n            "informing statement": 30,\n            "question": 9,\n            "acceptance": 6,\n            "challenge": 20,\n            "rejection": 9,\n            "accusation": 16,\n            "proposal": 6,\n            "evaluation": 9,\n            "denial": 4,\n            "request": 10,\n            "apology": 2,\n            "admission": 3\n        },\n        "number_of_tokens_per_tag": {},\n        "number_of_tokens": {\n            "total": 3487,\n            "min": 1,\n            "max": 239,\n            "avg": 25.82962962962963\n        }\n    },\n    "DEV": {\n        "dataset": "DEV",\n        "total_number_of_documents": 135,\n        "number_of_documents_per_class": {\n            "appreciation": 11,\n            "denial": 5,\n            "informing statement": 30,\n            "challenge": 20,\n            "request": 10,\n            "accusation": 16,\n            "proposal": 6,\n            "question": 9,\n            "admission": 3,\n            "acceptance": 6,\n            "apology": 2,\n            "evaluation": 9,\n            "rejection": 8\n        },\n        "number_of_tokens_per_tag": {},\n        "number_of_tokens": {\n            "total": 4744,\n            "min": 1,\n            "max": 1956,\n            "avg": 35.14074074074074\n        }\n    }\n}'

# %%
corpus.make_label_dictionary(label_type='action')
# Out:
# 2023-07-20 12:19:28,272 Computing label dictionary. Progress:
# 406it [00:00, 67593.67it/s]
# 2023-07-20 12:19:28,285 Dictionary created for label 'action' with 14 values: informing statement (seen 89 times), challenge (seen 61 times), accusation (seen 48 times), appreciation (seen 35 times), request (seen 29 times), evaluation (seen 28 times), rejection (seen 26 times), question (seen 26 times), acceptance (seen 20 times), proposal (seen 18 times), denial (seen 13 times), admission (seen 8 times), apology (seen 5 times)

# %% [markdown]
# ## Training starts!

# %%
config = {
    'learning_rate': 0.0008208788674713021,
 'max_epochs': 58,
 'mini_batch_size': 1,
      'mini_batch_chunk_size':4,  
}

# %%
import torch
torch.cuda.empty_cache()
tars = TARSClassifier.load('tars-base')
tars.add_and_switch_to_new_task("Dialogue_action",label_type='action', multi_label=multi_label, label_dictionary=corpus.make_label_dictionary(label_type='action'))
trainer = ModelTrainer(tars, corpus)
score = trainer.train(base_path='resources/taggers/action',
              train_with_dev=True,
                create_file_logs=True,
                create_loss_file=True,
                save_final_model=True,
                main_evaluation_metric = ("macro avg", "f1-score"),
               optimizer=torch.optim.SGD,
               **config,
              )
# Out:
# 2023-07-20 15:58:20,485 TARS initialized without a task. You need to call .add_and_switch_to_new_task() before training this model
# 2023-07-20 15:58:20,594 Computing label dictionary. Progress:
# 406it [00:00, 68170.03it/s]
# 2023-07-20 15:58:20,606 Dictionary created for label 'action' with 14 values: informing statement (seen 89 times), challenge (seen 61 times), accusation (seen 48 times), appreciation (seen 35 times), request (seen 29 times), evaluation (seen 28 times), rejection (seen 26 times), question (seen 26 times), acceptance (seen 20 times), proposal (seen 18 times), denial (seen 13 times), admission (seen 8 times), apology (seen 5 times)
# 2023-07-20 15:58:20,634 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:58:20,637 Model: "TARSClassifier(
#   (tars_model): TextClassifier(
#     (embeddings): TransformerDocumentEmbeddings(
#       (model): BertModel(
#         (embeddings): BertEmbeddings(
#           (word_embeddings): Embedding(30522, 768, padding_idx=0)
#           (position_embeddings): Embedding(512, 768)
#           (token_type_embeddings): Embedding(2, 768)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder): BertEncoder(
#           (layer): ModuleList(
#             (0-11): 12 x BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (pooler): BertPooler(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (activation): Tanh()
#         )
#       )
#     )
#     (decoder): Linear(in_features=768, out_features=2, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (locked_dropout): LockedDropout(p=0.0)
#     (word_dropout): WordDropout(p=0.0)
#     (loss_function): CrossEntropyLoss()
#   )
# )"
# 2023-07-20 15:58:20,639 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:58:20,640 Corpus: "Corpus: 406 train + 135 dev + 135 test sentences"
# 2023-07-20 15:58:20,642 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:58:20,643 Parameters:
# 2023-07-20 15:58:20,645  - learning_rate: "0.000821"
# 2023-07-20 15:58:20,646  - mini_batch_size: "1"
# 2023-07-20 15:58:20,648  - patience: "3"
# 2023-07-20 15:58:20,649  - anneal_factor: "0.5"
# 2023-07-20 15:58:20,651  - max_epochs: "58"
# 2023-07-20 15:58:20,652  - shuffle: "True"
# 2023-07-20 15:58:20,654  - train_with_dev: "True"
# 2023-07-20 15:58:20,655  - batch_growth_annealing: "False"
# 2023-07-20 15:58:20,656 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:58:20,658 Model training base path: "resources/taggers/action"
# 2023-07-20 15:58:20,659 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:58:20,660 Device: cuda:0
# 2023-07-20 15:58:20,660 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:58:20,661 Embeddings storage mode: cpu
# 2023-07-20 15:58:20,662 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15
#             request     0.2857    0.6667    0.4000         3
#          evaluation     0.5000    0.1667    0.2500         6
#          acceptance     1.0000    1.0000    1.0000         3
#            proposal     0.0000    0.0000    0.0000         4
#              denial     0.0000    0.0000    0.0000         3
#             apology     1.0000    1.0000    1.0000         2
#           admission     0.0000    0.0000    0.0000         1
#
#            accuracy                         0.4815       135
#           macro avg     0.5075    0.4715    0.4271       135
#        weighted avg     0.6997    0.4815    0.4924       135
#
# 2023-07-20 16:11:15,295 ----------------------------------------------------------------------------------------------------

# %%
# tars = TARSClassifier.load('resources/taggers/action/final-model.pt') ,

# %%
sentence = Sentence("i loved the spiderman movie!")

tars.predict(sentence)
print(sentence)

sentence = Sentence("pineapple on pizza is the worst 🤮")

tars.predict(sentence)
print(sentence)
# Out:
# Sentence[6]: "i loved the spiderman movie!" → appreciation (0.9994)
# Sentence[7]: "pineapple on pizza is the worst 🤮" → evaluation (0.9943)

# %%
tars.predict(sentences['test'], return_probabilities_for_all_classes=True, label_threshold=10**-7, multi_label=multi_label)

# %% [markdown]
# ## Evaluation starts!

# %%
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix

labels = classes = ['informing statement',
 'challenge',
 'accusation',
 'rejection',
 'appreciation',
 'request',
 'question',
 'evaluation', #
 'proposal', #
 'acceptance',
 'denial', #
 'admission', #
 'apology']

# %%
def get_multi_label_pred(sentences):
    ses = set()
    output = []
    for sentence in sentences:
        if sentence not in ses:
            ses.add(sentence)
        else:
            continue
            
        preds = []
        scores = []
        for i in sentence.labels:
            if i.score>=0.01:
                preds.append(i.value)
                scores.append(i.score)
        output.append(preds[:len(preds)//2])
    output = [[1 if j in i else 0 for j in labels] for i in output]
    return output
    
def get_multi_label_true(data):
    output = []
    for i, row in data.iterrows():
        row_labels = []
        row_labels.append(row['primary tag'])
        if str(row['secondary tag']) != 'nan':
            row_labels.append(row['secondary tag'])
        if str(row['tertiary']) != 'nan':
            row_labels.append(row['tertiary'])
        output.append(row_labels)
    output = [[1 if j in o else 0 for j in labels] for o in output]
    return output

if multi_label:
    y_pred = get_multi_label_pred(sentences['test'])
    y_true = get_multi_label_true(test)
    print(len(y_pred), len(y_true))

# %%
def get_score(sentences):
    scores = np.array([i.score for i in sentences])
    idx = np.argsort(scores)
    scores = scores[idx][::-1]
    return scores

def get_label(sentences):
    scores = np.array([i.score for i in sentences])
    labels = np.array([i.value for i in sentences])
    idx = np.argsort(scores)
    labels = labels[idx][::-1]
    return labels
    
if not multi_label:
    y_pred = np.array([get_label(i.labels)[0] for i in sentences['test']])
    y_scores = np.array([get_score(i.labels)[0] for i in sentences['test']])
    y_true = test['primary tag'].apply(lambda x: labels.index(x)).values
    y_pred = np.array([labels.index(i) for i in y_pred])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


def print_confusion_matrix(confusion_matrix, axes, class_label, class_names, fontsize=14):

    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names,
    )

    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d", cbar=False, ax=axes)
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    axes.set_ylabel('True label')
    axes.set_xlabel('Predicted label')
    axes.set_title("Confusion Matrix for the class - " + class_label)

# %% [markdown]
# #### Confusion Matrix

# %%
if not multi_label:

    cm = confusion_matrix(y_true, y_pred)
    df_cm = pd.DataFrame(cm, index = labels, columns = labels)
    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=True)
else:
    cm = multilabel_confusion_matrix(y_true, y_pred)
    
    fig, ax = plt.subplots(5, 3, figsize=(12, 12))
    
    for axes, cfs_matrix, label in zip(ax.flatten(), cm, labels):
        print_confusion_matrix(cfs_matrix, axes, label, ["N", "Y"])

    fig.tight_layout()
    plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=labels, zero_division=0))
# Out:
#                      precision    recall  f1-score   support
#
# informing statement       0.50      0.80      0.62        30
#           challenge       0.41      0.35      0.38        20
#          accusation       0.30      0.44      0.36        16
#           rejection       0.57      0.44      0.50         9
#        appreciation       0.83      0.91      0.87        11
#             request       1.00      0.70      0.82        10
#            question       0.55      0.67      0.60         9
#          evaluation       0.00      0.00      0.00         9
#            proposal       1.00      0.17      0.29         6
#          acceptance       0.67      0.33      0.44         6
#              denial       0.50      0.25      0.33         4
#           admission       0.00      0.00      0.00         3
#             apology       1.00      1.00      1.00         2
#
#            accuracy                           0.53       135
#           macro avg       0.56      0.47      0.48       135
#        weighted avg       0.53      0.53      0.50       135

# %%
micro_f1_score = f1_score(y_true, y_pred, average='micro')
print('f1-score micro', f1_score(y_true, y_pred, average='micro'))

macro_f1_score = f1_score(y_true, y_pred, average='macro')
print('f1-score macro', macro_f1_score)

weighted_f1_score = f1_score(y_true, y_pred, average='weighted')
print('f1-score weighted', weighted_f1_score)

if not multi_label:
    balanced_accuracy = balanced_accuracy_score(y_true, y_pred)
    print('balanced accuracy ', balanced_accuracy)
else:
    accuracy = accuracy_score(y_true, y_pred)
    print('accuracy ', accuracy)
# Out:
# f1-score micro 0.5259259259259259
# f1-score macro 0.47764031118349437
# f1-score weighted 0.4976851333032066
# balanced accuracy  0.4659770784770784

# %%
test['y_pred'] = y_pred
test['y_scores'] = y_scores
test['y_true'] = y_true

for i, label in enumerate(labels):
    print(label)
    t = test[test['y_true'] == i]
    t = t.sort_values(by=['y_scores'], ascending=True)
    t['y_scores'] = t['y_scores'].apply(lambda x: np.round(x, 3))
    
    r = t[t['y_pred']!=i]
    g = t[t['y_pred']==i]
    
    plt.figure()
    r.y_scores.hist(color=['red'], alpha=0.4, bins=list(np.arange(0.1,1.1, 0.05)))
    g.y_scores.hist(color=['green'], alpha=0.4, bins=list(np.arange(0.1,1.1, 0.05)))
    plt.show()
# Out:
# informing statement
# challenge
# accusation
# rejection
# appreciation
# request
# question
# evaluation
# proposal
# acceptance
# denial
# admission
# apology

# %%
# visualize
from flair.visual.training_curves import Plotter

plotter = Plotter()
plotter.plot_training_curves('resources/taggers/action/loss.tsv')
# plotter.plot_weights('resources/taggers/action/weights.txt')
# Out:
# 2023-07-20 16:11:33,077 ----------------------------------------------------------------------------------------------------
# 2023-07-20 16:11:33,079 WARNING: No LOSS found for test split in this data.
# 2023-07-20 16:11:33,081 Are you sure you want to plot LOSS and not another value?
# 2023-07-20 16:11:33,082 ----------------------------------------------------------------------------------------------------
# 2023-07-20 16:11:33,103 ----------------------------------------------------------------------------------------------------
# 2023-07-20 16:11:33,105 WARNING: No F1 found for test split in this data.
# 2023-07-20 16:11:33,106 Are you sure you want to plot F1 and not another value?
# 2023-07-20 16:11:33,108 ----------------------------------------------------------------------------------------------------
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2023-07-20 16:11:33,891 Loss and F1 plots are saved in resources/taggers/action/training.png

# %% [markdown]
# ## Finding the  best learning rate

# %%
trainer = ModelTrainer(tars, corpus)
trainer.find_learning_rate(base_path='resources/taggers/action3',
              optimizer=torch.optim.SGD,
              mini_batch_size=10,
              )

# %% [markdown]
# ## Experiment on Required Training set Size

# %%
volumes = np.arange(0.2, 1.2, 0.2)
volumes
# Out:
# array([0.2, 0.4, 0.6, 0.8, 1. ])

# %%
metrics = []
for i in volumes:
    
    new_data = {'train': train.sample(frac = i), 'dev': dev.sample(frac = i), 'test':test}
    
    new_sentences = {}
    for i, d in new_data.items():
        new_sentences[i] = list()
        for j, row in d.iterrows():
            new_sentences[i].append(Sentence(row['Text']).add_label('action', row['primary tag'], 1.0))
            if two_label and str(row['secondary tag']) != 'nan':
                new_sentences[i].append(Sentence(row['Text']).add_label('action', row['secondary tag'], second_label_confidence))
            if three_label and str(row['tertiary']) != 'nan':
                new_sentences[i].append(Sentence(row['Text']).add_label('action', row['tertiary'], third_label_confidence))

    corpus = Corpus(**sentences)
    print('bookmark', len(new_sentences['train']), len(new_sentences['test']))
    torch.cuda.empty_cache()
    
    tars = TARSClassifier.load('tars-base')
    tars.add_and_switch_to_new_task("Dialogue_action",label_type='action', multi_label=multi_label, label_dictionary=corpus.make_label_dictionary(label_type='action'))
    trainer = ModelTrainer(tars, corpus)
    score = trainer.train(base_path='resources/taggers/action',
                  train_with_dev=True,
                    create_file_logs=True,
                    create_loss_file=True,
                    save_final_model=True,
                    main_evaluation_metric = ("macro avg", "f1-score"),
                   optimizer=torch.optim.SGD,
                   **config,
                  )
    
    y_pred = np.array([get_label(i.labels)[0] for i in sentences['test']])
    y_scores = np.array([get_score(i.labels)[0] for i in sentences['test']])
    y_true = test['primary tag'].apply(lambda x: labels.index(x)).values
    y_pred = np.array([labels.index(i) for i in y_pred])
    
    metrics.append(f1_score(y_true, y_pred, average='weighted'))
# Out:
# bookmark 139 229
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 20
#      17 print('bookmark', len(new_sentences['train']), len(new_sentences['test']))
#      18 torch.cuda.empty_cache()
# ---> 20 tars = TARSClassifier.load('tars-base')
#      21 tars.add_and_switch_to_new_task("Dialogue_action",label_type='action', multi_label=multi_label, label_dictionary=corpus.make_label_dictionary(label_type='action'))
#      22 trainer = ModelTrainer(tars, corpus)
#
# File /projappl/project_2004586/Faeze/env/lib/python3.9/site-packages/flair/models/tars_model.py:928, in TARSClassifier.load(cls, model_path)
#     924 @classmethod
#     925 def load(cls, model_path: Union[str, Path, Dict[str, Any]]) -> "TARSClassifier":
#     926     from typing import cast
# --> 928     return cast("TARSClassifier", super().load(model_path=model_path))
#
# File /projappl/project_2004586/Faeze/env/lib/python3.9/site-packages/flair/models/tars_model.py:323, in FewshotClassifier.load(cls, model_path)
#     319 @classmethod
#     320 def load(cls, model_path: Union[str, Path, Dict[str, Any]]) -> "FewshotClassifier":
#     321     from typing import cast
# --> 323     return cast("FewshotClassifier", super().load(model_path=model_path))
#
# File /projappl/project_2004586/Faeze/env/lib/python3.9/site-packages/flair/nn/model.py:559, in Classifier.load(cls, model_path)
#     555 @classmethod
#     556 def load(cls, model_path: Union[str, Path, Dict[str, Any]]) -> "Classifier":
#     557     from typing import cast
# --> 559     return cast("Classifier", super().load(model_path=model_path))
#
# File /projappl/project_2004586/Faeze/env/lib/python3.9/site-packages/flair/nn/model.py:191, in Model.load(cls, model_path)
#     189 if not isinstance(model_path, dict):
#     190     model_file = cls._fetch_model(str(model_path))
# --> 191     state = load_torch_state(model_file)
#     192 else:
#     193     state = model_path
#
# File /projappl/project_2004586/Faeze/env/lib/python3.9/site-packages/flair/file_utils.py:359, in load_torch_state(model_file)
#     355 # load_big_file is a workaround byhttps://github.com/highway11git
#     356 # to load models on some Mac/Windows setups
#     357 # see https://github.com/zalandoresearch/flair/issues/351
#     358 f = load_big_file(model_file)
# --> 359 return torch.load(f, map_location="cpu")
#
# File /usr/local/lib64/python3.9/site-packages/torch/serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     807             except RuntimeError as e:
#     808                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 809         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     810 if weights_only:
#     811     try:
#
# File /usr/local/lib64/python3.9/site-packages/torch/serialization.py:1172, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1170 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1171 unpickler.persistent_load = persistent_load
# -> 1172 result = unpickler.load()
#    1174 torch._utils._validate_loaded_sparse_tensors()
#    1176 return result
#
# File /usr/local/lib64/python3.9/site-packages/torch/serialization.py:1142, in _load.<locals>.persistent_load(saved_id)
#    1140 else:
#    1141     nbytes = numel * torch._utils._element_size(dtype)
# -> 1142     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1144 return typed_storage
#
# File /usr/local/lib64/python3.9/site-packages/torch/serialization.py:1112, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1109 def load_tensor(dtype, numel, key, location):
#    1110     name = f'data/{key}'
# -> 1112     storage = zip_file.get_storage_from_record(name, numel, torch.UntypedStorage)._typed_storage()._untyped_storage
#    1113     # TODO: Once we decide to break serialization FC, we can
#    1114     # stop wrapping with TypedStorage
#    1115     typed_storage = torch.storage.TypedStorage(
#    1116         wrap_storage=restore_location(storage, location),
#    1117         dtype=dtype,
#    1118         _internal=True)
#
# KeyboardInterrupt:

# %%
metrics
# Out:
# []

# %% [markdown]
# ## Finding the best hyperparameters

# %%
def objective(trial):
    params = {
        'max_epochs': trial.suggest_int('max_epochs', 10, 100),
        'learning_rate': trial.suggest_float("learning_rate", 1e-6, 1e-1, log=True),
        'mini_batch_size': trial.suggest_int('mini_batch_size', 1, 8),
      'mini_batch_chunk_size':3,  
    }
    
#     if trial.params['optimizer'] == torch.optim.SGD:
#         scheduler = AnnealOnPlateau
#     else:
#         scheduler = LinearSchedulerWithWarmup
    
    
    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

    tars = TARSClassifier.load('tars-base')
    tars.add_and_switch_to_new_task('actions ' + str(trial.number), label_type='action', multi_label=multi_label, label_dictionary=corpus.make_label_dictionary(label_type='action'))
    trainer = ModelTrainer(tars, corpus)
    score = trainer.train(base_path='resources/taggers/'+str(trial.number),
                  learning_rate=params['learning_rate'],
                  mini_batch_size=params['mini_batch_size'],
                  max_epochs=params['max_epochs'],
                  optimizer=torch.optim.SGD,
                  param_selection_mode=True,
                    save_final_model=False,
                          
                  )
    
    tars.predict(sentences['test'], return_probabilities_for_all_classes=True, label_threshold=10**-7, multi_label=multi_label)

    
    return score['test_score']

# %%
study = optuna.create_study(study_name='new runs 2023 - 13 classes - single label',
                                    sampler=TPESampler(),
                                    direction="maximize",
                                    pruner=MedianPruner(n_startup_trials=5, n_warmup_steps=3),
                                    storage='sqlite:///optuna.db',
                                    load_if_exists=True,
                                    )
study.optimize(objective, n_trials=15)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial
print(' Number: ', trial.number)
print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2023-07-20 12:25:31,590] A new study created in RDB with name: new runs 2023 - 13 classes - single label
#   Params:
#     max_epochs: 53
#     learning_rate: 3.285686789444084e-05
#     mini_batch_size: 2
# 2023-07-20 12:25:39,128 TARS initialized without a task. You need to call .add_and_switch_to_new_task() before training this model
# 2023-07-20 12:25:39,234 Computing label dictionary. Progress:
# 406it [00:00, 69310.41it/s]
# 2023-07-20 12:25:39,245 Dictionary created for label 'action' with 14 values: informing statement (seen 89 times), challenge (seen 61 times), accusation (seen 48 times), appreciation (seen 35 times), request (seen 29 times), evaluation (seen 28 times), rejection (seen 26 times), question (seen 26 times), acceptance (seen 20 times), proposal (seen 18 times), denial (seen 13 times), admission (seen 8 times), apology (seen 5 times)
# 2023-07-20 12:25:39,252 ----------------------------------------------------------------------------------------------------
# 2023-07-20 12:25:39,255 Model: "TARSClassifier(
#   (tars_model): TextClassifier(
#     (embeddings): TransformerDocumentEmbeddings(
#       (model): BertModel(
#         (embeddings): BertEmbeddings(
#           (word_embeddings): Embedding(30522, 768, padding_idx=0)
#           (position_embeddings): Embedding(512, 768)
#           (token_type_embeddings): Embedding(2, 768)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder): BertEncoder(
#           (layer): ModuleList(
#             (0-11): 12 x BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (pooler): BertPooler(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (activation): Tanh()
#         )
#       )
#     )
#     (decoder): Linear(in_features=768, out_features=2, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (locked_dropout): LockedDropout(p=0.0)
#     (word_dropout): WordDropout(p=0.0)
#     (loss_function): CrossEntropyLoss()
#   )
# )"
# 2023-07-20 12:25:39,258 ----------------------------------------------------------------------------------------------------
# 2023-07-20 12
----------------------------------------------------------------------------------------------------
# 2023-07-20 15:54:53,933 EPOCH 33 done: loss 0.6034 - lr 0.000009
# 100%|██████████| 23/23 [00:18<00:00,  1.26it/s]
# 2023-07-20 15:55:12,152 Evaluating as a multi-label problem: False
# 2023-07-20 15:55:12,165 DEV : loss 0.38854697346687317 - f1-score (micro avg)  0.3481
# 2023-07-20 15:55:12,170 Epoch    33: reducing learning rate of group 0 to 4.4223e-06.
# 2023-07-20 15:55:12,172 BAD EPOCHS (no improvement): 4
# 2023-07-20 15:55:12,175 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:55:12,177 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:55:12,178 learning rate too small - quitting training!
# 2023-07-20 15:55:12,180 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:55:12,183 ----------------------------------------------------------------------------------------------------
# 2023-07-20 15:55:12,186 Testing using last state of model ...
# 100%|██████████| 23/23 [00:20<00:00,  1.14it/s]
# 2023-07-20 15:55:32,379 Evaluating as a multi-label problem: False
# 2023-07-20 15:55:32,391 0.5259	0.5259	0.5259	0.5259
# 2023-07-20 15:55:32,394
# Results:
# - F-score (micro) 0.5259
# - F-score (macro) 0.4012
# - Accuracy 0.5259
#
# By class:
#                      precision    recall  f1-score   support
#
# informing statement     1.0000    0.3288    0.4948        73
#           rejection     0.3226    1.0000    0.4878        10
#            question     0.5417    1.0000    0.7027        13
#           challenge     0.4667    0.4375    0.4516        16
#        appreciation     0.6875    1.0000    0.8148        11
#          accusation     0.6667    0.2500    0.3636         8
#          evaluation     0.0000    0.0000    0.0000         0
#            proposal     0.2500    1.0000    0.4000         1
#             apology     1.0000    1.0000    1.0000         2
#             request     0.3333    1.0000    0.5000         1
#          acceptance     0.0000    0.0000    0.0000         0
#              denial     0.0000    0.0000    0.0000         0
#           admission     0.0000    0.0000    0.0000         0
#
#            accuracy                         0.5259       135
#           macro avg     0.4053    0.5397    0.4012       135
#        weighted avg     0.7868    0.5259    0.5343       135
#
# 2023-07-20 15:55:32,396 ----------------------------------------------------------------------------------------------------
# [I 2023-07-20 15:55:51,841] Trial 14 finished with value: 0.5259259259259259 and parameters: {'max_epochs': 69, 'learning_rate': 7.075623670433796e-05, 'mini_batch_size': 6}. Best is trial 3 with value: 0.8888888888888888.
# Study statistics:
#   Number of finished trials:  15
#   Number of pruned trials:  0
#   Number of complete trials:  15
# Best trial:
#  Number:  3
#   Value:  0.8888888888888888
#   Params:
#     learning_rate: 0.0008208788674713021
#     max_epochs: 58
#     mini_batch_size: 1

# %%
trial
# Out:
# FrozenTrial(number=3, state=TrialState.COMPLETE, values=[0.8888888888888888], datetime_start=datetime.datetime(2023, 7, 20, 13, 5, 37, 423144), datetime_complete=datetime.datetime(2023, 7, 20, 13, 13, 31, 121857), params={'learning_rate': 0.0008208788674713021, 'max_epochs': 58, 'mini_batch_size': 1}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': FloatDistribution(high=0.1, log=True, low=1e-06, step=None), 'max_epochs': IntDistribution(high=100, log=False, low=10, step=1), 'mini_batch_size': IntDistribution(high=8, log=False, low=1, step=1)}, trial_id=236, value=None)

# %%
selected_params = trial.params
selected_params
# Out:
# {'learning_rate': 0.0008208788674713021,
#  'max_epochs': 58,
#  'mini_batch_size': 1}

# %%
from optuna.visualization.matplotlib import plot_param_importances

plot_param_importances(trial.backend)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 3
#       1 from optuna.visualization.matplotlib import plot_param_importances
# ----> 3 plot_param_importances(trial.backend)
#
# AttributeError: 'FrozenTrial' object has no attribute 'backend'
